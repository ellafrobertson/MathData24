# %% [markdown]
# <a href="https://colab.research.google.com/github/ellafrobertson/MathData24/blob/main/MathData_Class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://www.flbog.edu/wp-content/uploads/fau-masthead-1024x427-1.jpg" width=400>
# <img src="https://th.bing.com/th/id/OIP.2HQKw6GhCudVsOC8N2pLnAAAAA?rs=1&pid=ImgDetMain" width=400>

# %%
apples = 10

# %%
oranges = 8

# %%
total = apples + oranges

# %%
total
# Out:
# 18

# %%
print(total)
# Out:
# 18

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.random.random((1,5))

# %%
A
# Out:
# array([[0.58086937, 0.78520636, 0.12898437, 0.28705009, 0.07141212]])

# %%
B = np.random.random((1,5))

# %%
A,B
# Out:
# (array([[0.58086937, 0.78520636, 0.12898437, 0.28705009, 0.07141212]]),
#  array([[0.4151716 , 0.10257148, 0.36014739, 0.31397488, 0.15753959]]))

# %%
A = A.T
B = B.T
A, B
# Out:
# (array([[0.58086937],
#         [0.78520636],
#         [0.12898437],
#         [0.28705009],
#         [0.07141212]]),
#  array([[0.4151716 ],
#         [0.10257148],
#         [0.36014739],
#         [0.31397488],
#         [0.15753959]]))

# %%
plt.plot(A,B)

# %%
plt.plot(A,B,'r.')

# %%
X = np.random.random((100,1))
Y = np.random.random((100,1))
plt.plot(X,Y,'g--')

# %%
print(A.shape,B.shape,X.shape,Y.shape)
# Out:
# (5, 1) (5, 1) (100, 1) (100, 1)

# %%
Z = np.random.random((100,100))
Z.shape
Z
# Out:
# array([[0.92894253, 0.95235392, 0.72775771, ..., 0.95402708, 0.54422276,
#         0.62831239],
#        [0.11943836, 0.81193   , 0.67009909, ..., 0.07724058, 0.68935824,
#         0.1411197 ],
#        [0.08570111, 0.96416177, 0.16657538, ..., 0.56706916, 0.82923457,
#         0.073549  ],
#        ...,
#        [0.92607914, 0.35209564, 0.90142488, ..., 0.92351295, 0.97311777,
#         0.21222714],
#        [0.80710901, 0.29229324, 0.18951161, ..., 0.79951721, 0.89402294,
#         0.33415338],
#        [0.50679061, 0.04810525, 0.02516767, ..., 0.34358382, 0.38481681,
#         0.40850405]])

# %%
plt.imshow(Z)
